# %%
import numpy as np
import matplotlib.pyplot as plt

from supplier import Quality, Price
from utils import *
from const import *

# %%
x = np.linspace(1, 100, 100)

plt.plot([QUALITY_LOW_A, QUALITY_LOW_C, QUALITY_LOW_D], [1, 1, 0], label='low')
plt.plot([QUALITY_MEDIUM_A, QUALITY_MEDIUM_B, QUALITY_MEDIUM_C, QUALITY_MEDIUM_D], [0, 1, 1, 0], label='medium')
plt.plot([QUALITY_HIGH_A, QUALITY_HIGH_B, QUALITY_HIGH_C], [0, 1, 1], label='high')

plt.title('Quality')
plt.legend()
plt.ylim(0.01)
plt.show()

# %%
x = [i for i in range(1, 11)]

plt.plot([PRICE_CHEAP_A, PRICE_CHEAP_C, PRICE_CHEAP_D], [1, 1, 0], label='cheap')
plt.plot([PRICE_MEDIUM_A, PRICE_MEDIUM_B, PRICE_MEDIUM_C], [0, 1, 0], label='medium')
plt.plot([PRICE_EXPENSIVE_A, PRICE_EXPENSIVE_B, PRICE_EXPENSIVE_C], [0, 1, 1], label='expensive')

plt.title('Price')
plt.legend()
plt.ylim(0.01)
plt.show()

# %%
plt.plot([WORTHINESS_BAD_A, WORTHINESS_BAD_C, WORTHINESS_BAD_D], [1, 1, 0], label='bad')
plt.plot([WORTHINESS_GOOD_A, WORTHINESS_GOOD_B, WORTHINESS_GOOD_C, WORTHINESS_GOOD_D], [0, 1, 1, 0], label='good')
plt.plot([WORTHINESS_EXCELLENT_A, WORTHINESS_EXCELLENT_B, WORTHINESS_EXCELLENT_D], [0, 1, 1], label='excellent')

plt.title('Worthiness')
plt.legend()
plt.ylim(0.01)
plt.show()
